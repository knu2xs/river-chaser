# %%
from arcgis.gis import GIS, Item

# %%
gis = GIS('http://jdm1cc.maps.arcgis.com', 'joel_mccune')
# Out:
# Enter password: ········

# %%
qpf_item = Item(gis, '71afd16b8845426e9435c5dbb9ca8ea6')

# %%
layer = qpf_item.layers[0]

# %%
layer.query()
# Out:
# {
#   "currentVersion": 10.51,
#   "id": 0,
#   "name": "Amount by Time",
#   "type": "Feature Layer",
#   "description": "The amount of rainfall forecasted during each time interval.",
#   "geometryType": "esriGeometryPolygon",
#   "sourceSpatialReference": {
#     "wkid": 102100,
#     "latestWkid": 3857
#   },
#   "copyrightText": "NOAA, Esri",
#   "parentLayer": null,
#   "subLayers": [],
#   "minScale": 0,
#   "maxScale": 0,
#   "drawingInfo": {
#     "renderer": {
#       "type": "uniqueValue",
#       "field1": "category",
#       "field2": null,
#       "field3": null,
#       "defaultSymbol": null,
#       "defaultLabel": null,
#       "uniqueValueInfos": [
#         {
#           "symbol": {
#             "type": "esriSFS",
#             "style": "esriSFSSolid",
#             "color": [
#               190,
#               232,
#               255,
#               255
#             ],
#             "outline": {
#               "type": "esriSLS",
# ...
